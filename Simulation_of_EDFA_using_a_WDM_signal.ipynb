# %% [markdown]
# <a href="https://colab.research.google.com/github/kimheeseo/LSCNS/blob/main/Simulation_of_EDFA_using_a_WDM_signal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 출처: https://github.com/edsonportosilva/OptiCommPy/blob/main/examples/basic_EDFA.ipynb

# %%
if 'google.colab' in str(get_ipython()):
    ! git clone -b main https://github.com/edsonportosilva/OptiCommPy
    from os import chdir as cd
    cd('/content/OptiCommPy/')
    ! pip install .
# Out:
# fatal: destination path 'OptiCommPy' already exists and is not an empty directory.
# Processing /content/OptiCommPy
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (2.0.2)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (1.16.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (3.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (1.14.0)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (4.67.3)
# Requirement already satisfied: numba>=0.54.0 in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (0.60.0)
# Requirement already satisfied: simple-pid>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (2.0.1)
# Requirement already satisfied: mpl-scatter-density>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (0.8)
# Requirement already satisfied: sphinx-rtd-theme>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (3.1.0)
# Requirement already satisfied: nbsphinx>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (0.9.8)
# Requirement already satisfied: nbsphinx-link>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (1.3.1)
# Requirement already satisfied: prettytable>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from OptiCommPy==0.11.0) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.11.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.11.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.11.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.11.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.11.0) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.11.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.11.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->OptiCommPy==0.11.0) (2.9.0.post0)
# Requirement already satisfied: fast-histogram>=0.3 in /usr/local/lib/python3.12/dist-packages (from mpl-scatter-density>=0.7.0->OptiCommPy==0.11.0) (0.14)
# Requirement already satisfied: docutils>=0.18.1 in /usr/local/lib/python3.12/dist-packages (from nbsphinx>=0.9.3->OptiCommPy==0.11.0) (0.21.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from nbsphinx>=0.9.3->OptiCommPy==0.11.0) (3.1.6)
# Requirement already satisfied: nbconvert!=5.4,>=5.3 in /usr/local/lib/python3.12/dist-packages (from nbsphinx>=0.9.3->OptiCommPy==0.11.0) (7.17.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from nbsphinx>=0.9.3->OptiCommPy==0.11.0) (5.10.4)
# Requirement already satisfied: sphinx!=8.2.0,!=8.2.1,>=1.8 in /usr/local/lib/python3.12/dist-packages (from nbsphinx>=0.9.3->OptiCommPy==0.11.0) (8.2.3)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.12/dist-packages (from nbsphinx>=0.9.3->OptiCommPy==0.11.0) (5.7.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54.0->OptiCommPy==0.11.0) (0.43.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable>=3.16.0->OptiCommPy==0.11.0) (0.6.0)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.12/dist-packages (from sphinx-rtd-theme>=1.2.2->OptiCommPy==0.11.0) (4.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->OptiCommPy==0.11.0) (1.3.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (5.9.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2.19.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (4.26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->OptiCommPy==0.11.0) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2.18.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2.32.4)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (4.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.7->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (4.9.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (7.4.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30.0->sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2026.1.4)
# Requirement already satisfied: roman-numerals==4.1.0 in /usr/local/lib/python3.12/dist-packages (from roman-numerals-py>=1.0.0->sphinx!=8.2.0,!=8.2.1,>=1.8->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (4.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (4.15.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (1.6.0)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (26.2.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx>=0.9.3->OptiCommPy==0.11.0) (6.5.1)
# Building wheels for collected packages: OptiCommPy
#   Building wheel for OptiCommPy (setup.py) ... done
#   Created wheel for OptiCommPy: filename=OptiCommPy-0.11.0-py3-none-any.whl size=109779 sha256=c29419461d6050e8a07b5bc3e8a58e1935f0a9256e3478064130f65711bbe33d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ic3c5k_b/wheels/e7/51/a4/9a2d1dac30da20ac41d7157db2114765e1712b94ccc8944634
# Successfully built OptiCommPy
# Installing collected packages: OptiCommPy
#   Attempting uninstall: OptiCommPy
#     Found existing installation: OptiCommPy 0.11.0
#     Uninstalling OptiCommPy-0.11.0:
#       Successfully uninstalled OptiCommPy-0.11.0
# Successfully installed OptiCommPy-0.11.0

# %%
import os.path as path
import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import c
from scipy.signal import find_peaks

from optic.utils import parameters
from optic.models.amplification import edfaSM, OSA, power_meter, get_spectrum
from optic.dsp.core import phaseNoise

#import logging as logg
#logg.getLogger().setLevel(logg.INFO)
#logg.basicConfig(format='%(message)s')

# %%
from IPython.core.display import HTML
from IPython.core.pylabtools import figsize

HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
figsize(10, 3)

# %% [markdown]
# **Parameters**

# %%
# EDFA parameters:
param_edfa = parameters()
# Gain control
param_edfa.type     = "none"
param_edfa.value    = 20 #dB
# Pump configuration
param_edfa.forPump  = {'pump_signal': np.array([ 10e-3]), 'pump_lambda': np.array([980e-9])}
param_edfa.bckPump  = {'pump_signal': np.array([000e-3]), 'pump_lambda': np.array([980e-9])}
# EDF parameters
param_edfa.file     = 'giles_MP980.dat'
param_edfa.fileunit = 'nm'
# Algorithm
param_edfa.gmtc     = 'Bessel'
param_edfa.tol      = 0.05
param_edfa.tolCtrl  = 0.5

# %% [markdown]
# **실행 환경이 Colab인지 로컬인지 판단해서 EDFA 파라미터 파일 경로를 다르게 지정하는 코드**

# %%
if 'google.colab' in str(get_ipython()):
  param_edfa.file = path.join(path.abspath(path.join("../")), 'OptiCommPy', 'optic','models','ampParams', param_edfa.file)
else:
  param_edfa.file = path.join(path.abspath(path.join("../")), 'optic','models','ampParams', param_edfa.file)

# %%
param_edfa.file
# Out:
# '/content/OptiCommPy/optic/models/ampParams/giles_MP980.dat'

# %%
# Transmitter parameters:
paramTx = parameters()
paramTx.NSb = 2**10          # number os symbols: 총 심볼 개수=길이 길수록 BER 정확도 향상
paramTx.SpS = 256            # samples per symbol
paramTx.Rs  = 30e9           # symbol rate, 1초에 몇 개의 심볼을 보내는
paramTx.lw  = 1e6            # laser linewidth, 레이저의 주파수 흔들림 정도
paramTx.Nch = 2              # number of channels
paramTx.Nmodes   = 1         # number of modes
paramTx.Pch_dBm  = -40       # channel power
paramTx.freqSpac = 2.5e12    # channel bandwith
paramTx.Fc       = c/1540e-9 # central frequency

# %% [markdown]
# **Simulation**

# %%
# 1. Signal generation
# CW signal with two optical channels: 1530 and 1550 nm.
t = np.arange(0, paramTx.NSb * paramTx.SpS)
Fs = paramTx.Rs*paramTx.SpS

# central frequencies of the WDM channels
freqGrid = (
    np.arange(-np.floor(paramTx.Nch / 2), np.floor(paramTx.Nch / 2) + 1, 1)
    * paramTx.freqSpac
)
if (paramTx.Nch % 2) == 0:
    freqGrid += paramTx.freqSpac / 2 # 채널이 짝수이면 중심이 0Hz에 오지 않게 이동
# linear power
power_lin = 10**((paramTx.Pch_dBm)/10 - 3) # dBm->Watt 변환

# comb generation
sigTxWDM = np.zeros((len(t), paramTx.Nmodes), dtype="complex")
for indCh in range(paramTx.Nch): # 채널별 comb 생성 루프
    for indMode in range(paramTx.Nmodes):
        pho_pn_lo = phaseNoise(paramTx.lw, len(t), 1/Fs) # 레이저 linewidth에 따른 random phase 생성
        sigLO   = np.sqrt(power_lin)*np.exp(1j*pho_pn_lo) # 위상 잡음이 들어간 CW 레이저 전기장 유도
        sigTxWDM[:, indMode] += sigLO * np.exp(1j * 2 * np.pi * (freqGrid[indCh] / Fs) * t)
# sigLO * np.exp(1j * 2 * np.pi * (freqGrid[indCh] / Fs) * t): 주파수 쉬프트
# sigTxWDM[:, indMode] +=: WDM 합성 유

#* pho_pn_lo: 레이저의 위상값을 고려하기 위한 것
#  레이저 linewidth에 의해 발생하는 시간에 따른 랜덤 위상 변화

#* sigLO: 레이저의 복소 전기장(복소 포락선: 캐리어 제거된 전기장)
#  레이저의 실제 전기장을 복소수로 표현한 것

#* sigTxWDM: 각 레이저를 서로 다른 주파수로 이동시켜 WDM 신호를 만드는 것

# %% [markdown]
# ![제목 없음.png](data:image/png;base64,...)

# %%
ax = OSA(sigTxWDM, Fs, paramTx.Fc)
ax.set_xlim([1520,1560])
ax.set_ylim([-120,-35])
# Out:
# (-120.0, -35.0)

# %%
simOpticalBand = (Fs*(c/paramTx.Fc)**2)/c
tx_power = 1000*power_meter(sigTxWDM)
# information TX
print('Number of points: %d' %(len(sigTxWDM)))
print('Sample rate [THz]: %5.3f' %(1e-12*Fs))
print('Time window [ns]:  %5.3f' %(1e9*len(sigTxWDM)/Fs))
print('Frequency spacing [GHz]: %f' %(1e-9*Fs/len(sigTxWDM)))
print('')
print('Number of modes: %d' %(paramTx.Nmodes))
print('Central wavelength [nm]: %6.2f' %(1e9*c/paramTx.Fc))
print('Simulation window  [nm]: %f - [%6.2f nm - %6.2f nm]'
      %(1e9*simOpticalBand, 1e9*(c/paramTx.Fc-simOpticalBand/2), 1e9*(c/paramTx.Fc+simOpticalBand/2)))
print('')
print('Average power - TX [mW] : %.3f mW' %(tx_power))
print('Average power - TX [dBm] : %.3f dBm' %(10*np.log10(tx_power)))
# Out:
# Number of points: 262144
# Sample rate [THz]: 7.680
# Time window [ns]:  34.133
# Frequency spacing [GHz]: 0.029297
#
# Number of modes: 1
# Central wavelength [nm]: 1540.00
# Simulation window  [nm]: 60.754991 - [1509.62 nm - 1570.38 nm]
#
# Average power - TX [mW] : 0.000 mW
# Average power - TX [dBm] : -36.990 dBm

# %% [markdown]
# **Signal amplification**

# %%
#%load_ext line_profiler: 함수 실행 시간을 줄 단위로 측정
#%lprun -f edfaSM edfaSM(sigWDM_Tx, Fs, paramTx.Fc, param_edfa): edfaSM 함수에서 어느 부분이 느린지 분석
# EDFA 계산이 느릴때, Ramon solver/Giles model이 병목인지 확인할 때 사용

# amplification
Eout, PumpF, PumpB, noisef = edfaSM(sigTxWDM, Fs, paramTx.Fc, param_edfa)

# 입력값:
# 1) sigTxWDM: EDFA 입력 광신호: 복소 전기장, 편광 포함 가능, WDM 채널 포함
# 2) Fs: 샘플링 주파수
# 3) paramTx.Fc: 광 중심 주파수
# 4) param_edfa: EDFA 물리 모델 파라미터

# 출력값:
# 1) Eout: EDFA 출력 광신호
# 2) PumpF: forward pump power 분포
# 3) PumpB: backward pump power 분포
# 4) noisef: ASE noise 스펙트럼

# %%
# information amp
rx_pw = 1000*power_meter(Eout)
print('Forward pump  - [mW] : %.3f' %(1e3*PumpF[0]))
print('Backward pump - [mW] : %.3f' %(1e3*PumpB[1]))
print('')
print('Average power - RX amp [mW] : %.3f' %(rx_pw))
print('Average power - RX amp [dBm] : %.3f' %(10*np.log10(rx_pw)))
print('Gain [dB]: %.3f' %(10*np.log10(rx_pw/tx_power)))
# Out:
# Forward pump  - [mW] : 10.000
# Backward pump - [mW] : 0.000
#
# Average power - RX amp [mW] : 0.120
# Average power - RX amp [dBm] : -9.205
# Gain [dB]: 27.784

# %%
ax = OSA(Eout, Fs, paramTx.Fc)
ax.set_xlim([1520,1570])
ax.set_ylim([-70,-15])
# Out:
# (-70.0, -15.0)

# %% [markdown]
# **EDFA Analysis**

# %% [markdown]
# Considering two pump signals: 980 nm and 1480 nm for different forward pump powers.

# %%
def find_nearest(array, value):
    array = np.asarray(array)
    return (np.abs(array - np.transpose([value]))).argmin(axis=1)
# 주어진 값에 가장 가까운 배열 index 찾기
# frequency grid에서 채널 중심주파수에 가장 가까 bin 찾음

def get_channels_power(signal, Fs, Fc, channels, resolution = 1e-9):
    frequency, spectrum = get_spectrum(signal, Fs, Fc)
    index_ch = find_nearest(frequency, channels) # 각 채널 중심 주파수에 대응하는 FFT bin index: 채널 위치 찾

    channel_power = np.zeros(len(index_ch))
    for i in range(len(index_ch)):
        # index = ((frequency[index_ch[i]] > frequency-resolution/2) == (frequency[index_ch[i]] < frequency+resolution/2))
        index = ((frequency[index_ch[i]] > frequency-resolution/2) & (frequency[index_ch[i]] < frequency+resolution/2))
        # 채널 bandwidth 내 주파수 선택, 원래 코드 ===>&
        # 채널 중심 주파수 주변, resolution만큼의 bandwidh 안에 스펙트럼만 측
        channel_power[i] = np.sum(10**(spectrum[index]/10)) # 파워 합
    return 10*np.log10(channel_power)

  # get_channels_power: WDM 각 채널의 광파워를 계산하는 함수
  # 이 링크에서 각 채널이 몇 dBm으로 들어가고 나오는 지 확인하는 파워 미터

# %% [markdown]
# ![스크린샷 2026-02-25 232242.png](data:image/png;base64,...)

# %%
# Channels for monitoring
channels = np.array([1530e-9,1550e-9])
# Pump signal wavelength
pump_signal_wavelength = np.array([980e-9,1480e-9])
# forward pump array
forPump =  np.linspace(5e-3, 40e-3, 10)
# Create variables
noise = np.zeros([len(forPump),len(pump_signal_wavelength)])
amp_signal_power = np.zeros([len(forPump),len(pump_signal_wavelength)])
channels_power = np.zeros([len(forPump),len(pump_signal_wavelength),len(channels)])

# %%
# 980 and 1480 nm
for j in range(len(pump_signal_wavelength)):
    param_edfa.forPump['pump_lambda'] = np.array([pump_signal_wavelength[j]])
    for i in range(len(forPump)):
        param_edfa.forPump['pump_signal']  = np.array([forPump[i]])
        Eout, PumpF, PumpB, noisef = edfaSM(sigTxWDM, Fs, paramTx.Fc, param_edfa)
        # Noise power
        noise[i,j] = 1e3*power_meter(noisef)
        # Total power
        amp_signal_power[i,j] = 1e3*power_meter(Eout)
        # Channels power
        channels_power[i,j,:] = get_channels_power(Eout[:,0], Fs, paramTx.Fc, channels)
# Signal and channel gain
amp_signal_gain = 10*np.log10(amp_signal_power/tx_power)
channels_power_gain = 10*np.log10(channels_power)
# Out:
# /tmp/ipython-input-1255210400.py:15: RuntimeWarning: invalid value encountered in log10
#   channels_power_gain = 10*np.log10(channels_power)

# %% [markdown]
# **graph**

# %%
fig, ax = plt.subplots(1,2,figsize=(12,6))
ax[0].plot(1e3*forPump, amp_signal_gain[:,0], 'o-', color = 'firebrick', lw = 2, label = '980 nm')
ax[0].plot(1e3*forPump, channels_power[:,0,0] - paramTx.Pch_dBm, 'o--', color = 'red', lw = 2, label = '1530 nm - 980 nm')
ax[0].plot(1e3*forPump, channels_power[:,0,1] - paramTx.Pch_dBm, 'o--', color = 'darksalmon', lw = 2, label = '1550 nm - 980 nm')
ax[0].plot(1e3*forPump, amp_signal_gain[:,1], 's-', color = 'navy', lw = 2, label = '1480 nm')
ax[0].plot(1e3*forPump, channels_power[:,1,0] - paramTx.Pch_dBm, 's--', color = 'blue', lw = 2, label = '1530 nm - 1480 nm')
ax[0].plot(1e3*forPump, channels_power[:,1,1] - paramTx.Pch_dBm, 's--', color = 'royalblue', lw = 2, label = '1550 nm - 1480 nm')

ax[0].set_xlabel('Forward pump [mW]')
ax[0].set_ylabel('Gain [dB]')
ax[0].set_ylim([5,50])
ax[0].set_xlim([1e3*forPump.min(),1e3*forPump.max()])
ax[0].grid(True)
ax[0].legend(loc='upper left')

ax[1].plot(1e3*forPump, 10*np.log10(noise[:,0]), 'o-', color = 'firebrick', lw = 2, label = '980 nm')
ax[1].plot(1e3*forPump, 10*np.log10(noise[:,1]), 'o-', color = 'navy', lw = 2, label = '1480 nm')
ax[1].set_xlabel('Forward pump [mW]')
ax[1].set_ylabel('ASE power [dBm]')
ax[1].set_xlim([1e3*forPump.min(),1e3*forPump.max()])
ax[1].grid(True)
ax[1].legend(loc='upper left')
